# %%
import pandas as pd
import numpy as np
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import json
from pandas.io.json import json_normalize
import ast

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

# %%
df_ari_ml = pd.read_excel(open('data/Book1.xlsx', 'rb'), header=None)

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Odds')
plt.ylabel('Captured times')
plt.title('Moneyline odds movements for Arizona Diamondbacks 2017 MLB season, first 53 games')
plt.plot(df_ari_ml)
plt.show()

# %%
df_ari_ml2 = pd.read_excel(open('data/Book3.xlsx', 'rb'), header=None)

# %%
#len(df_ari_ml2[df_ari_ml2[2] == 50][1])
# Out:
# 248

# %%
# game 1, many data points because betting opened several days before the game actually occurred
df_ari_ml2[df_ari_ml2[2] == 1][1].plot()

# %%
# game 2
df_ari_ml2[df_ari_ml2[2] == 2][1].plot()

# %%
# game 3
df_ari_ml2[df_ari_ml2[2] == 3][1].plot()

# %%
# game 4
df_ari_ml2[df_ari_ml2[2] == 4][1].plot()

# %%
# game 5
df_ari_ml2[df_ari_ml2[2] == 5][1].plot()

# %%
# game 6
df_ari_ml2[df_ari_ml2[2] == 6][1].plot()

# %%
# game 7
df_ari_ml2[df_ari_ml2[2] == 7][1].plot()

# %%
# game 8
df_ari_ml2[df_ari_ml2[2] == 8][1].plot()

# %%
# game 9
df_ari_ml2[df_ari_ml2[2] == 9][1].plot()

# %%
# game 10
df_ari_ml2[df_ari_ml2[2] == 10][1].plot()
